# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/Colab Notebooks/Snn_Starter")

# %%
# !ls
# Out:
# checkpoint  dataset_test.py  self_spiking_model.py  test.py	 train.py
# dataset     __pycache__      snn_dataset.py	    train.ipynb

# %%
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch [56/500], Step [100/100], Loss: 0.27068
# Time elasped: 56.94524788856506
# 0 20  Acc: 78.00000
# Iters: 56
# Test Accuracy of the model on the 10000 test images: 79.200
# Epoch [57/500], Step [25/100], Loss: 0.27360
# Time elasped: 14.268649816513062
# Epoch [57/500], Step [50/100], Loss: 0.31397
# Time elasped: 28.69437050819397
# Epoch [57/500], Step [75/100], Loss: 0.27210
# Time elasped: 42.80879259109497
# Epoch [57/500], Step [100/100], Loss: 0.27162
# Time elasped: 56.95287895202637
# 0 20  Acc: 84.00000
# Iters: 57
# Test Accuracy of the model on the 10000 test images: 79.500
# Epoch [58/500], Step [25/100], Loss: 0.26249
# Time elasped: 14.360502243041992
# Epoch [58/500], Step [50/100], Loss: 0.24968
# Time elasped: 28.809617042541504
# Epoch [58/500], Step [75/100], Loss: 0.26770
# Time elasped: 42.99638056755066
# Epoch [58/500], Step [100/100], Loss: 0.28519
# Time elasped: 57.19146490097046
# ...

# %% [markdown]
# epoch = 500 训练之后在测试数据集上的结果
#
# 大约有97%左右的准确性，训练样例如下所示
#
# 执行测试文件时请务必确保test.py与self_spiking_model.py文件中定义的batch_size参数保持一致

# %%
# !python test.py
# Out:
# python3: can't open file 'test.py': [Errno 2] No such file or directory
